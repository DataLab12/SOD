# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %%
data_dict= {'Model': ['Baseline', 'Baseline', 'Baseline with focal loss', 'Baseline with focal loss', 'Baseline with Difficulty Module', 'Baseline with Difficulty Module', 'Our Proposed Model', 'Our Proposed Model'], 
            'mAP': [17.13,  49.20, 18.29, 51.3, 19.32, 52.10, 21.5, 54.67] , 'Dataset':['DOTA', 'DIOR', 'DOTA', 'DIOR', 'DOTA', 'DIOR', 'DOTA', 'DIOR'] }

# %%
df= pd.read_csv("/home/ubq3/Downloads/performance_results.csv")

# %%
#df= pd.DataFrame.from_dict(data_dict)

# %%
df.head(10)
# Out:
#   Model  Dataset  Precision  Recall        F1     mAP
# 0  Base  DOTA2.0     0.1785  0.3431  0.234829  0.1713
# 1  Base     DIOR     0.4970  0.5430  0.518983  0.4960
# 2   SOD  DOTA2.0     0.1927  0.3650  0.248589  0.1886
# 3   SOD     DIOR     0.5220  0.5580  0.533467  0.5190

# %%
# sns.set(font_scale = .8)

# g = sns.catplot(
#     data=df, kind="bar",
#     x="Model", y="mAP", hue="Dataset",
#     ci="sd", palette="dark", alpha=.7,
# )
# g.fig.set_size_inches(12, 8)
# g.despine(left=True)
# g.set_axis_labels("Evaluated Model", "mAP")
# g.legend.set_title("")


# g.fig.subplots_adjust(top=0.81, right=0.86)

# # extract the matplotlib axes_subplot objects from the FacetGrid
# ax = g.facet_axis(0, 0)

# # iterate through the axes containers

# sns.set(font_scale = 1.5)
sns.set(rc={'font.size': 10, 'axes.facecolor':'white', 'figure.facecolor':'white', "figure.dpi":200, 'savefig.dpi':200})
iverging_colors =  sns.color_palette("bright")
plt.rc('xtick', labelsize=14)
plt.rc('ytick', labelsize=14)
# Set the axes labels font size
plt.rc('axes', labelsize=14)
# Set the legend font size
plt.rc('legend', fontsize=14)

g = sns.catplot(
    data=df, kind="bar",
    x="Model", y="Recall", hue="Dataset",
    ci="sd", palette= iverging_colors , alpha= 1, height=4
)
g.fig.set_size_inches(6, 4)
# g.despine(left=True)
g.set_axis_labels("Evaluated Model", "Recall")
g.legend.set_title("")
g.set(ylim=(0, 0.65))
ax = g.facet_axis(0, 0)

for c in ax.containers:
    labels = [f'{(v.get_height()):.3f}' for v in c]
    ax.bar_label(c, labels=labels, label_type='edge')

# def change_width(ax, new_value) :
#     for patch in ax.patches :
#         current_width = patch.get_width()
#         diff = current_width - new_value

#         # we change the bar width
#         patch.set_width(new_value)

#         # we recenter the bar
#         patch.set_x(patch.get_x() + diff * .5)

# change_width(ax, .20)

plt.show()

# %%
df.plot.bar(x='Model', y='Precision', rot=0)

# %%
import matplotlib.pyplot as plt
import seaborn
seaborn.set(rc={'axes.facecolor':'white', 'figure.facecolor':'white'})

fig, ax = plt.subplots()

# %%
diverging_colors = sns.color_palette("deep", 8)
sns.palplot(diverging_colors)

# %%
sns.set(font_scale = .8)

g = sns.barplot(
    data=df, x="Model", y="mAP", hue="Dataset", errwidth=0
)

for i in g.containers:
    g.bar_label(i,)

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x, labels)
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)

fig.tight_layout()

plt.show()
